# %% [markdown]
# <a href="https://colab.research.google.com/github/JonCro1978/JC-Colab-Rep/blob/main/JCv_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Zoe is a geebag, mofo')
# Out:
# Zoe is a geebag, mofo

# %%
U=('UNA Mofo')
print(U)
# Out:
# UNA Mofo

# %%
#API allows machines interact with exch other!
