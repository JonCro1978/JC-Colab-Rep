# %% [markdown]
# <a href="https://colab.research.google.com/github/JonCro1978/JC-Colab-Rep/blob/main/JC_sams_Class_20_1_26.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('Is this working')
# Out:
# Is this working

# %%
print('I dont beleive it is')
# Out:
# I dont beleive it is
